# %%
import pandas as pd

# Load csv file to DataFrame
df = pd.read_csv("hw_work.csv")
print(df.info()) # organic data, meta data
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %% [markdown]
# <h3 style="color:blue;">The column 'Total day minutes' is missing 10 values.</h3>

# %% [markdown]
# <h3 style="color:blue;">DataFrame 'memory usage: 520.9+ KB'.</h3>

# %% [markdown]
# ### חקור את כל עמודות הטבלה באמצעות describe מה הערך הכי גבוה עבור עמודת עמודת length Account ###

# %%
print(df.describe())  # statistics
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3323.000000
# mean       101.064806   437.182418               8.099010         179.787150
# std         39.822106    42.371290              13.688365          54.419625
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.500000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3323.000000       3315.000000        3324.000000      3325.000000
# mean        100.456214         30.557831         201.033935       100.110677
# ...

# %% [markdown]
# ### The max value of Account length column is: 243 ###

# %%
print(df.head()) # Display 5 first line as default
print(df.tail()) # Display 5 last line as default
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %%
print(df.iloc[14]) # print index(14) line 15
# Out:
# State                        OH
# Account length              107
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        26
# Total day minutes         161.6
# Total day calls           123.0
# Total day charge          27.47
# Total eve minutes         195.5
# Total eve calls           103.0
# Total eve charge          16.62
# Total night minutes       254.4
# Total night calls         103.0
# Total night charge        11.45
# Total intl minutes         13.7
# Total intl calls              3
# Total intl charge           3.7
# Customer service calls      1.0
# Churn                     False
# Name: 1, dtype: object

# %%
print(df.iloc[14:])
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 14      IA              62        415                 No              No
# 15      NY             161        415                 No              No
# 16      ID              85        408                 No             Yes
# 17      VT              93        510                 No              No
# 18      VA              76        510                 No             Yes
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# ### מחק את עמודת code Area , רמז drop לפי axis של עמודה ###

# %%
df.drop(columns=['Area code','Total day minutes']) # drop column
# Out:
#      State  Account length International plan Voice mail plan  \
# 0       KS             128                 No             Yes
# 1       OH             107                 No             Yes
# 2       NJ             137                 No              No
# 3       OH              84                Yes              No
# 4       OK              75                Yes              No
# ...    ...             ...                ...             ...
# 3328    AZ             192                 No             Yes
# 3329    WV              68                 No              No
# 3330    RI              28                 No              No
# 3331    CT             184                Yes              No
# 3332    TN              74                 No             Yes
#
#       Number vmail messages  Total day calls  Total day charge  \
# 0                        25            110.0             45.07
# 1                        26            123.0             27.47
# ...

# %%
df.drop('Area code', axis=1) # drop column
# Out:
#      State  Account length International plan Voice mail plan  \
# 0       KS             128                 No             Yes
# 1       OH             107                 No             Yes
# 2       NJ             137                 No              No
# 3       OH              84                Yes              No
# 4       OK              75                Yes              No
# ...    ...             ...                ...             ...
# 3328    AZ             192                 No             Yes
# 3329    WV              68                 No              No
# 3330    RI              28                 No              No
# 3331    CT             184                Yes              No
# 3332    TN              74                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1            110.0
# 1                        26              161.6            123.0
# ...

# %% [markdown]
# ### מחק את שורה 3328, רמז drop לפי axis של שורה ###

# %%
df.drop(3328, axis=0)# drop line 3328
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3327    SC              79        415                 No              No
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# <div dir="rtl">
# ### שאלה חוב -- חשב בעמודה חדשה בשם total_min את סכום העמודות: Total intl minutes + Total night minutes ###
# </div>

# %%
df = df[['Total intl minutes', 'Total night minutes']].copy()
df['Total_min'] = df['Total intl minutes'] + df['Total night minutes']
print(df.head())
# Out:
#    Total intl minutes  Total night minutes  Total_min
# 0                10.0                244.7      254.7
# 1                13.7                254.4      268.1
# 2                12.2                162.6      174.8
# 3                 6.6                196.9      203.5
# 4                10.1                186.9      197.0

# %%
print(df.columns.tolist()) # print all the columns
# Out:
# ['Total intl minutes', 'Total night minutes', 'Total_min']

# %% [markdown]
# <div dir="rtl">
# ###  צור DF חדש המורכב מהשורה הראשונה והאחרונה של הטבלה הנוכחית באמצעות concat התעלם מהאינקסים הקודמים בזמן החיבור ###
# </div>

# %%
combined_df = pd.concat([df.iloc[0],df.iloc[-1]])# אני לא יודע לסדר את זה, אבל זה אמור לעבוד
print(df_combined)
# Out:
#      A  B    C
# 0  1.0  3  NaN
# 1  2.0  4  NaN
# 0  NaN  7  5.0
# 1  NaN  8  6.0

# %% [markdown]
# <div dir="rtl">
# ###  השימוש ב- inpalce מאפשר לשנות את DF ###
# ### אם inplace=False מחזיר עותק חדש ###
# ### inplace=True משנה את DF ###
# ### רק שרוצים שה- DF ישתנה נשתמש ב- פונקציה, ברירת מחדל שלה False  לרוב הפונקציה לא תחזיר ערך מאחר ###
# </div>
